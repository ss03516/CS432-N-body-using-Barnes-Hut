# %% [markdown]
# <div align="center"><h1>N-Body Problem</h1></div>

# %% [markdown]
# In
# physics
# and
# astronomy,
# an
# N-­‐body
# simulation
# is
# a
# simulation
# of
# a
# dynamical
# system
# of
# particles,
# usually
# under
# the
# influence
# of
# physical
# forces,
# such
# as
# gravity.
# Direct
# N-­‐body
# simulations
# are
# used
# to
# study
# the
# dynamical
# evolution
# of
# star
# clusters.
# Beyond
# gravitational
# masses,
# a
# variety
# of
# physical
# systems
# can
# be
# modeled
# by
# the
# interaction
# of
# N
# particles,
# e.g.,
# atoms
# or
# ions
# under
# electrostatics
# and
# van
# der
# Waals
# forces
# lead
# to
# molecular
# dynamics.
# Also,
# the
# integral
# formulation
# of
# problems
# modeled
# by
# elliptic
# partial
# differential
# equations
# leads
# to
# numerical
# integration
# having
# the
# same
# form,
# computationally,
# as
# an
# N-­‐body
# interaction.
# In
# this
# way,
# Nbody
# algorithms
# are
# applicable
# to
# acoustics,
# electromagnetics,
# and
# fluid
# dynamics.
# Adding
# to
# this
# diversity
# of
# applications,
# radiosity
# algorithms
# for
# global
# illumination
# problems
# in
# computer
# graphics
# also
# benefit
# from
# N-­‐body
# methods.

# %%
# !nvidia-smi
# Out:
# Thu Dec  3 22:52:35 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.33.01    Driver Version: 440.33.01    CUDA Version: 10.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:1E.0 Off |                    0 |
# | N/A   34C    P0    36W / 300W |      0MiB / 16160MiB |      5%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Serial Barnes-Hut

# %%
# !nvcc -o SerialBarnesHut Barnes-Hut-Cpp.cpp -lm

# %%
# !./SerialBarnesHut
# Out:
# configuration: 100 bodies, 1 time steps
#
# 1.377000 ms
# Timestep 0 Center of Mass = (-1.069650e-01,-2.987980e-02,1.083692e-01)

# %%
# !nsys profile --stats=true --force-overwrite true -o barnesHutProfile ./SerialBarnesHut
# Out:
# Warning: LBR backtrace method is not supported on this platform. DWARF backtrace method will be used.
# Collecting data...
# The target application terminated. One or more process it created re-parented.
# Waiting for termination of re-parented processes.
# Use the `--wait` option to modify this behavior.
# 1.396000 ms
# Timestep 0 Center of Mass = (-1.069650e-01,-2.987980e-02,1.083692e-01)
# configuration: 100 bodies, 1 time steps
#
# Processing events...
# Capturing symbol files...
# Saving temporary "/tmp/nsys-report-a735-4ad1-166c-2a01.qdstrm" file to disk...
# Creating final output files...
#
# Processing [==============================================================100%]
# Saved report file to "/tmp/nsys-report-a735-4ad1-166c-2a01.qdrep"
# Exporting 42 events: [====================================================100%]
#
# Exported successfully to
# /tmp/nsys-report-a735-4ad1-166c-2a01.sqlite
#
# Generating CUDA API Statistics...
# CUDA API Statistics (nanoseconds)
#
#
#
#
# CUDA trace data was not collected.
#
#
# Generating Operating System Runtime API Statistics...
# Operating System Runtime API Statistics (nanoseconds)
#
# Time(%)      Total Time       Calls         Average         Minimum         Maximum  Name
# -------  --------------  ----------  --------------  --------------  --------------  --------------------------------------------------------------------------------
#    75.9           11941           6          1990.2            1096            5475  fwrite
#    17.0            2680           2          1340.0            1099            1581  putc
#     7.0            1102           1          1102.0            1102            1102  fflush
#
#
#
#
# Generating NVTX Push-Pop Range Statistics...
# NVTX Push-Pop Range Statistics (nanoseconds)
#
#
#
#
# Report file moved to "/dli/task/barnesHutProfile.qdrep"
# Report file moved to "/dli/task/barnesHutProfile.sqlite"

# %%
# !nvprof ./SerialBarnesHut
# Out:
# configuration: 100 bodies, 1 time steps
#
# 1.401000 ms
# Timestep 0 Center of Mass = (-1.069650e-01,-2.987980e-02,1.083692e-01)
# ======== Warning: No profile data collected.

# %% [markdown]
# # NAIVE BARNES HUT:

# %%
!(cd DynamicPar_NlogN/ && ls)
# Out:
# Constants.h  build.bash        cudaBhtree.cu  cudanlogn.cu
# a.out	     createVideo.bash  cudaOctant.cu  deleteImgs.bash

# %%
!(cd DynamicPar_NlogN/ && chmod u+x cudanlogn.cu)

# %%
!(cd DynamicPar_NlogN/ && nvcc -o NaiveParallel -std=c++11 -rdc=true -arch=sm_70 cudanlogn.cu -run)
# Out:
# Nbodies: 100
#
# Each Particle weight: 3e+28
# ______________________________
#
# Beginning timestep: 1
# calculating force from star...
# Building octree...
# calculating interactions...
# updating particle positions...
# -------Done------- timestep: 1
#
# Beginning timestep: 2
# calculating force from star...
# Building octree...
# calculating interactions...
# updating particle positions...
# -------Done------- timestep: 2
#
# Beginning timestep: 3
# calculating force from star...
# Building octree...
# calculating interactions...
# updating particle positions...
# -------Done------- timestep: 3
#
# Beginning timestep: 4
# calculating force from star...
# Building octree...
# calculating interactions...
# updating particle positions...
# -------Done------- timestep: 4
#
# we made it

# %%
!(cd DynamicPar_NlogN/ && nvprof ./NaiveParallel)
# Out:
# Nbodies: 100
# ==1143== NVPROF is profiling process 1143, command: ./NaiveParallel
#
# Each Particle weight: 3e+28
# ______________________________
#
# ==1143== Warning: CDP tracing and profiling are not supported on devices with compute capability 7.0 and later.
# Beginning timestep: 1
# calculating force from star...
# Building octree...
# calculating interactions...
# updating particle positions...
# -------Done------- timestep: 1
#
# Beginning timestep: 2
# calculating force from star...
# Building octree...
# calculating interactions...
# updating particle positions...
# -------Done------- timestep: 2
#
# Beginning timestep: 3
# calculating force from star...
# Building octree...
# calculating interactions...
# updating particle positions...
# -------Done------- timestep: 3
#
# Beginning timestep: 4
# calculating force from star...
# Building octree...
# calculating interactions...
# updating particle positions...
# -------Done------- timestep: 4
#
# we made it
# ==1143== Profiling application: ./NaiveParallel
# ==1143== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   78.59%  8.9280us         4  2.2320us  1.8240us  3.1360us  [CUDA memcpy DtoH]
#                    21.41%  2.4320us         1  2.4320us  2.4320us  2.4320us  [CUDA memcpy HtoD]
#       API calls:   93.05%  3.31934s         5  663.87ms  36.526us  1.19899s  cudaMemcpy
#                     6.91%  246.65ms         1  246.65ms  246.65ms  246.65ms  cudaMalloc
#                     0.02%  707.47us         1  707.47us  707.47us  707.47us  cuDeviceTotalMem
#                     0.01%  314.57us         4  78.641us  22.007us  246.59us  cudaLaunchKernel
#                     0.01%  276.53us        96  2.8800us     617ns  72.756us  cuDeviceGetAttribute
#                     0.00%  21.002us         1  21.002us  21.002us  21.002us  cuDeviceGetName
#                     0.00%  5.0630us         4  1.2650us  1.0680us  1.7120us  cudaGetLastError
#                     0.00%  3.6390us         3  1.2130us     661ns  1.7730us  cuDeviceGetCount
#                     0.00%  3.5660us         1  3.5660us  3.5660us  3.5660us  cuDeviceGetPCIBusId
#                     0.00%  2.0710us         2  1.0350us     728ns  1.3430us  cuDeviceGet
#                     0.00%     797ns         1     797ns     797ns     797ns  cuDeviceGetUuid

# %%
!(cd DynamicPar_NlogN/ && nsys profile --stats=true --force-overwrite true -o NaiveParallelProfile ./NaiveParallel)
# Out:
# Warning: LBR backtrace method is not supported on this platform. DWARF backtrace method will be used.
# Collecting data...
# Nbodies: 100
#
# Each Particle weight: 3e+28
# ______________________________
#
# Beginning timestep: 1
# calculating force from star...
# Building octree...
# calculating interactions...
# updating particle positions...
# -------Done------- timestep: 1
#
# Beginning timestep: 2
# calculating force from star...
# Building octree...
# calculating interactions...
# updating particle positions...
# -------Done------- timestep: 2
#
# Beginning timestep: 3
# calculating force from star...
# Building octree...
# calculating interactions...
# updating particle positions...
# -------Done------- timestep: 3
#
# Beginning timestep: 4
# calculating force from star...
# Building octree...
# calculating interactions...
# updating particle positions...
# -------Done------- timestep: 4
#
# we made it
# Processing events...
# Capturing symbol files...
# Saving temporary "/tmp/nsys-report-a18d-207f-ad90-9406.qdstrm" file to disk...
# Creating final output files...
#
# Processing [==============================================================100%]
# Saved report file to "/tmp/nsys-report-a18d-207f-ad90-9406.qdrep"
# Exporting 1075 events: [==================================================100%]
#
# Exported successfully to
# /tmp/nsys-report-a18d-207f-ad90-9406.sqlite
#
# Generating CUDA API Statistics...
# CUDA API Statistics (nanoseconds)
#
# Time(%)      Total Time       Calls         Average         Minimum         Maximum  Name
# -------  --------------  ----------  --------------  --------------  --------------  --------------------------------------------------------------------------------
#    90.6      2411038542           5     482207708.4           27696       704352731  cudaMemcpy
#     9.4       250496389           1     250496389.0       250496389       250496389  cudaMalloc
#     0.0          287351           4         71837.7           21598          203538  cudaLaunchKernel
#
#
#
#
#
# Generating CUDA Memory Operation Statistics...
# CUDA Memory Operation Statistics (nanoseconds)
#
# Time(%)      Total Time  Operations         Average         Minimum         Maximum  Name
# -------  --------------  ----------  --------------  --------------  --------------  --------------------------------------------------------------------------------
#    78.3            8672           4          2168.0            1856            2752  [CUDA memcpy DtoH]
#    21.7            2400           1          2400.0            2400            2400  [CUDA memcpy HtoD]
#
#
# CUDA Memory Operation Statistics (KiB)
#
#               Total      Operations              Average            Minimum              Maximum  Name
# -------------------  --------------  -------------------  -----------------  -------------------  --------------------------------------------------------------------------------
#               7.813               1                7.813              7.813                7.813  [CUDA memcpy HtoD]
#              31.250               4                7.813              7.813                7.813  [CUDA memcpy DtoH]
#
#
#
#
# Generating Operating System Runtime API Statistics...
# Operating System Runtime API Statistics (nanoseconds)
#
# Time(%)      Total Time       Calls         Average         Minimum         Maximum  Name
# -------  --------------  ----------  --------------  --------------  --------------  --------------------------------------------------------------------------------
#    49.8      2702794116          37      73048489.6           26780       100128769  sem_timedwait
#    48.0      2605188552          37      70410501.4           50555       100187165  poll
#     2.0       110444553         589        187512.0            1042        20599595  ioctl
#     0.1         2711555          81         33476.0            1707          809056  mmap
#     0.0          680948          73          9328.1            3984           19507  open64
#     0.0          156733           4         39183.3           37225           41925  pthread_create
#     0.0          122078          11         11098.0            7458           16722  write
#     0.0          112339          21          5349.5            1588           16879  fopen
#     0.0           96226           3         32075.3           24612           45349  fgets
#     0.0           90857          17          5344.5            1329           16656  fwrite
#     0.0           73320          68          1078.2            1020            1510  fcntl
#     0.0           41441           5          8288.2            4257           14667  open
#     0.0           36689          14          2620.6            1616            4172  fclose
#     0.0           34837          13          2679.8            1337            6031  read
#     0.0           32948           9          3660.9            1797            6199  munmap
#     0.0           16889           3          5629.7            5334            6029  pipe2
#     0.0           11062           8          1382.8            1018            1822  fflush
#     0.0           10201           2          5100.5            4866            5335  socket
#     0.0           10081           4          2520.3            2237            2952  mprotect
#     0.0            7182           1          7182.0            7182            7182  connect
#     0.0            3040           1          3040.0            3040            3040  bind
#     0.0            2058           1          2058.0            2058            2058  listen
#
#
#
#
# Generating NVTX Push-Pop Range Statistics...
# NVTX Push-Pop Range Statistics (nanoseconds)
#
#
#
#
# Report file moved to "/dli/task/DynamicPar_NlogN/NaiveParallelProfile.qdrep"
# Report file moved to "/dli/task/DynamicPar_NlogN/NaiveParallelProfile.sqlite"

# %% [markdown]
# # Barnes-Hut Algorithm Optimized With Shared Memory

# %%
!(cd BarnesHut-SharedMemory/ && nvcc -arch=sm_70 -o barnesHut main.cu )

# %%
!(cd BarnesHut-SharedMemory/ && ./barnesHut 10000 100 0 )
# Out:
# Device count: 1configuration: 10000 bodies, 100 time steps
# Start of timestep
# TIMESTEP = 0
# TIMESTEP = 1
# TIMESTEP = 2
# TIMESTEP = 3
# TIMESTEP = 4
# TIMESTEP = 5
# TIMESTEP = 6
# TIMESTEP = 7
# TIMESTEP = 8
# TIMESTEP = 9
# TIMESTEP = 10
# TIMESTEP = 11
# TIMESTEP = 12
# TIMESTEP = 13
# TIMESTEP = 14
# TIMESTEP = 15
# TIMESTEP = 16
# TIMESTEP = 17
# TIMESTEP = 18
# TIMESTEP = 19
# TIMESTEP = 20
# TIMESTEP = 21
# TIMESTEP = 22
# TIMESTEP = 23
# TIMESTEP = 24
# TIMESTEP = 25
# TIMESTEP = 26
# TIMESTEP = 27
# TIMESTEP = 28
# TIMESTEP = 29
# TIMESTEP = 30
# TIMESTEP = 31
# TIMESTEP = 32
# TIMESTEP = 33
# TIMESTEP = 34
# TIMESTEP = 35
# TIMESTEP = 36
# TIMESTEP = 37
# TIMESTEP = 38
# TIMESTEP = 39
# TIMESTEP = 40
# TIMESTEP = 41
# TIMESTEP = 42
# TIMESTEP = 43
# TIMESTEP = 44
# TIMESTEP = 45
# TIMESTEP = 46
# TIMESTEP = 47
# TIMESTEP = 48
# TIMESTEP = 49
# TIMESTEP = 50
# TIMESTEP = 51
# TIMESTEP = 52
# TIMESTEP = 53
# TIMESTEP = 54
# TIMESTEP = 55
# TIMESTEP = 56
# TIMESTEP = 57
# TIMESTEP = 58
# TIMESTEP = 59
# TIMESTEP = 60
# TIMESTEP = 61
# TIMESTEP = 62
# TIMESTEP = 63
# TIMESTEP = 64
# TIMESTEP = 65
# TIMESTEP = 66
# TIMESTEP = 67
# TIMESTEP = 68
# TIMESTEP = 69
# TIMESTEP = 70
# TIMESTEP = 71
# TIMESTEP = 72
# TIMESTEP = 73
# TIMESTEP = 74
# TIMESTEP = 75
# TIMESTEP = 76
# TIMESTEP = 77
# TIMESTEP = 78
# TIMESTEP = 79
# TIMESTEP = 80
# TIMESTEP = 81
# TIMESTEP = 82
# TIMESTEP = 83
# TIMESTEP = 84
# TIMESTEP = 85
# TIMESTEP = 86
# TIMESTEP = 87
# TIMESTEP = 88
# TIMESTEP = 89
# TIMESTEP = 90
# TIMESTEP = 91
# TIMESTEP = 92
# TIMESTEP = 93
# TIMESTEP = 94
# TIMESTEP = 95
# TIMESTEP = 96
# TIMESTEP = 97
# TIMESTEP = 98
# TIMESTEP = 99
# runtime: 0.0338 s  ( 5.7  6.3  6.2  3.7  2.0  1.0 ) = 24.9 ms

# %%
!(cd BarnesHut-SharedMemory/ && nvprof ./barnesHut 10000 100 0 )
# Out:
# ==947== NVPROF is profiling process 947, command: ./barnesHut 10000 100 0
# Device count: 1configuration: 10000 bodies, 100 time steps
# Start of timestep
# TIMESTEP = 0
# TIMESTEP = 1
# TIMESTEP = 2
# TIMESTEP = 3
# TIMESTEP = 4
# TIMESTEP = 5
# TIMESTEP = 6
# TIMESTEP = 7
# TIMESTEP = 8
# TIMESTEP = 9
# TIMESTEP = 10
# TIMESTEP = 11
# TIMESTEP = 12
# TIMESTEP = 13
# TIMESTEP = 14
# TIMESTEP = 15
# TIMESTEP = 16
# TIMESTEP = 17
# TIMESTEP = 18
# TIMESTEP = 19
# TIMESTEP = 20
# TIMESTEP = 21
# TIMESTEP = 22
# TIMESTEP = 23
# TIMESTEP = 24
# TIMESTEP = 25
# TIMESTEP = 26
# TIMESTEP = 27
# TIMESTEP = 28
# TIMESTEP = 29
# TIMESTEP = 30
# TIMESTEP = 31
# TIMESTEP = 32
# TIMESTEP = 33
# TIMESTEP = 34
# TIMESTEP = 35
# TIMESTEP = 36
# TIMESTEP = 37
# TIMESTEP = 38
# TIMESTEP = 39
# TIMESTEP = 40
# TIMESTEP = 41
# TIMESTEP = 42
# TIMESTEP = 43
# TIMESTEP = 44
# TIMESTEP = 45
# TIMESTEP = 46
# TIMESTEP = 47
# TIMESTEP = 48
# TIMESTEP = 49
# TIMESTEP = 50
# TIMESTEP = 51
# TIMESTEP = 52
# TIMESTEP = 53
# TIMESTEP = 54
# TIMESTEP = 55
# TIMESTEP = 56
# TIMESTEP = 57
# TIMESTEP = 58
# TIMESTEP = 59
# TIMESTEP = 60
# TIMESTEP = 61
# TIMESTEP = 62
# TIMESTEP = 63
# TIMESTEP = 64
# TIMESTEP = 65
# TIMESTEP = 66
# TIMESTEP = 67
# TIMESTEP = 68
# TIMESTEP = 69
# TIMESTEP = 70
# TIMESTEP = 71
# TIMESTEP = 72
# TIMESTEP = 73
# TIMESTEP = 74
# TIMESTEP = 75
# TIMESTEP = 76
# TIMESTEP = 77
# TIMESTEP = 78
# TIMESTEP = 79
# TIMESTEP = 80
# TIMESTEP = 81
# TIMESTEP = 82
# TIMESTEP = 83
# TIMESTEP = 84
# TIMESTEP = 85
# TIMESTEP = 86
# TIMESTEP = 87
# TIMESTEP = 88
# TIMESTEP = 89
# TIMESTEP = 90
# TIMESTEP = 91
# TIMESTEP = 92
# TIMESTEP = 93
# TIMESTEP = 94
# TIMESTEP = 95
# TIMESTEP = 96
# TIMESTEP = 97
# TIMESTEP = 98
# TIMESTEP = 99
# runtime: 0.0397 s  ( 6.1  7.0  6.6  4.2  2.2  1.3 ) = 27.5 ms
# ==947== Profiling application: ./barnesHut 10000 100 0
# ==947== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   27.23%  5.7710ms       100  57.709us  53.153us  65.025us  CoGKernel(int, int, int volatile *, int const *, float volatile *, float volatile *, float volatile *, float volatile *)
#                    23.79%  5.0418ms       100  50.417us  44.320us  58.880us  TreeBuildingKernel(int, int, int volatile *, float volatile *, float volatile *, float volatile *)
#                    23.62%  5.0051ms       100  50.051us  47.649us  53.281us  BoundingBoxKernel(int, int, int volatile *, int volatile *, float volatile *, float volatile *, float volatile *, float volatile *, float volatile *, float volatile *, float volatile *, float volatile *, float volatile *, float volatile *)
#                    15.62%  3.3106ms       100  33.105us  30.048us  37.888us  SortKernel(int, int, int*, int*, int volatile *, int*)
#                     6.24%  1.3222ms       100  13.221us  9.8880us  13.632us  ForceKernel(int, int, float, float, float, int volatile *, int volatile *, float volatile *, float volatile *, float volatile *, float volatile *, float volatile *, float volatile *, float volatile *, float volatile *, float volatile *, float volatile *)
#                     1.27%  268.23us       100  2.6820us  2.5920us  5.3760us  InitializationKernel1(int, int, int volatile *)
#                     1.23%  260.10us       100  2.6000us  2.5600us  2.8160us  UpdateKernel(int, float, float, float*, float*, float*, float*, float*, float*, float*, float*, float*)
#                     0.68%  143.33us       100  1.4330us  1.3760us  1.6640us  InitializationKernel2(int, int volatile *, float volatile *)
#                     0.20%  41.409us         7  5.9150us  5.8880us  5.9210us  [CUDA memcpy HtoD]
#                     0.12%  24.641us         6  4.1060us  3.9690us  4.4800us  [CUDA memcpy DtoH]
#                     0.01%  2.9440us         1  2.9440us  2.9440us  2.9440us  InitializationKernel(void)
#       API calls:   96.50%  1.05225s         8  131.53ms     932ns  1.05224s  cudaFuncSetCacheConfig
#                     2.03%  22.142ms       601  36.841us  6.6260us  77.682us  cudaEventSynchronize
#                     0.58%  6.3666ms       801  7.9480us  6.5240us  36.954us  cudaLaunchKernel
#                     0.34%  3.6638ms      1202  3.0480us  2.3980us  19.466us  cudaEventRecord
#                     0.19%  2.0732ms       635  3.2640us  2.7050us  13.078us  cudaDeviceSynchronize
#                     0.09%  1.0148ms       601  1.6880us  1.4350us  3.1130us  cudaEventElapsedTime
#                     0.07%  712.89us         1  712.89us  712.89us  712.89us  cuDeviceTotalMem
#                     0.06%  633.13us        20  31.656us  4.1520us  156.81us  cudaMalloc
#                     0.04%  457.11us       636     718ns     582ns  1.9180us  cudaGetLastError
#                     0.03%  303.80us        13  23.369us  15.205us  39.521us  cudaMemcpy
#                     0.03%  275.28us        96  2.8670us     618ns  72.463us  cuDeviceGetAttribute
#                     0.02%  210.76us         1  210.76us  210.76us  210.76us  cudaGetDeviceProperties
#                     0.02%  208.78us        13  16.059us  2.9680us  144.38us  cudaFree
#                     0.00%  20.635us         1  20.635us  20.635us  20.635us  cuDeviceGetName
#                     0.00%  9.2700us         1  9.2700us  9.2700us  9.2700us  cudaSetDevice
#                     0.00%  6.4610us         1  6.4610us  6.4610us  6.4610us  cudaGetDeviceCount
#                     0.00%  5.8150us         2  2.9070us  1.5160us  4.2990us  cudaEventCreate
#                     0.00%  4.2980us         3  1.4320us     618ns  1.9620us  cuDeviceGetCount
#                     0.00%  4.2730us         1  4.2730us  4.2730us  4.2730us  cuDeviceGetPCIBusId
#                     0.00%  3.8930us         2  1.9460us  1.3170us  2.5760us  cudaEventDestroy
#                     0.00%  2.8420us         2  1.4210us     717ns  2.1250us  cuDeviceGet
#                     0.00%     761ns         1     761ns     761ns     761ns  cuDeviceGetUuid

# %%
!(cd BarnesHut-SharedMemory/ && nsys profile --stats=true --force-overwrite true -o barnesHutProfile ./barnesHut 10000 100 0)
# Out:
# Warning: LBR backtrace method is not supported on this platform. DWARF backtrace method will be used.
# Collecting data...
# Device count: 1configuration: 10000 bodies, 100 time steps
# Start of timestep
# TIMESTEP = 0
# TIMESTEP = 1
# TIMESTEP = 2
# TIMESTEP = 3
# TIMESTEP = 4
# TIMESTEP = 5
# TIMESTEP = 6
# TIMESTEP = 7
# TIMESTEP = 8
# TIMESTEP = 9
# TIMESTEP = 10
# TIMESTEP = 11
# TIMESTEP = 12
# TIMESTEP = 13
# TIMESTEP = 14
# TIMESTEP = 15
# TIMESTEP = 16
# TIMESTEP = 17
# TIMESTEP = 18
# TIMESTEP = 19
# TIMESTEP = 20
# TIMESTEP = 21
# TIMESTEP = 22
# TIMESTEP = 23
# TIMESTEP = 24
# TIMESTEP = 25
# TIMESTEP = 26
# TIMESTEP = 27
# TIMESTEP = 28
# TIMESTEP = 29
# TIMESTEP = 30
# TIMESTEP = 31
# TIMESTEP = 32
# TIMESTEP = 33
# TIMESTEP = 34
# TIMESTEP = 35
# TIMESTEP = 36
# TIMESTEP = 37
# TIMESTEP = 38
# TIMESTEP = 39
# TIMESTEP = 40
# TIMESTEP = 41
# TIMESTEP = 42
# TIMESTEP = 43
# TIMESTEP = 44
# TIMESTEP = 45
# TIMESTEP = 46
# TIMESTEP = 47
# TIMESTEP = 48
# TIMESTEP = 49
# TIMESTEP = 50
# TIMESTEP = 51
# TIMESTEP = 52
# TIMESTEP = 53
# TIMESTEP = 54
# TIMESTEP = 55
# TIMESTEP = 56
# TIMESTEP = 57
# TIMESTEP = 58
# TIMESTEP = 59
# TIMESTEP = 60
# TIMESTEP = 61
# TIMESTEP = 62
# TIMESTEP = 63
# TIMESTEP = 64
# TIMESTEP = 65
# TIMESTEP = 66
# TIMESTEP = 67
# TIMESTEP = 68
# TIMESTEP = 69
# TIMESTEP = 70
# TIMESTEP = 71
# TIMESTEP = 72
# TIMESTEP = 73
# TIMESTEP = 74
# TIMESTEP = 75
# TIMESTEP = 76
# TIMESTEP = 77
# TIMESTEP = 78
# TIMESTEP = 79
# TIMESTEP = 80
# TIMESTEP = 81
# TIMESTEP = 82
# TIMESTEP = 83
# TIMESTEP = 84
# TIMESTEP = 85
# TIMESTEP = 86
# TIMESTEP = 87
# TIMESTEP = 88
# TIMESTEP = 89
# TIMESTEP = 90
# TIMESTEP = 91
# TIMESTEP = 92
# TIMESTEP = 93
# TIMESTEP = 94
# TIMESTEP = 95
# TIMESTEP = 96
# TIMESTEP = 97
# TIMESTEP = 98
# TIMESTEP = 99
# runtime: 0.0397 s  ( 6.1  7.0  6.7  4.2  2.2  1.3 ) = 27.5 ms
# Processing events...
# Capturing symbol files...
# Saving temporary "/tmp/nsys-report-6daf-ba9d-f340-578f.qdstrm" file to disk...
# Creating final output files...
#
# Processing [==============================================================100%]
# Saved report file to "/tmp/nsys-report-6daf-ba9d-f340-578f.qdrep"
# Exporting 6317 events: [==================================================100%]
#
# Exported successfully to
# /tmp/nsys-report-6daf-ba9d-f340-578f.sqlite
#
# Generating CUDA API Statistics...
# CUDA API Statistics (nanoseconds)
#
# Time(%)      Total Time       Calls         Average         Minimum         Maximum  Name
# -------  --------------  ----------  --------------  --------------  --------------  --------------------------------------------------------------------------------
#    63.7        22581838         601         37573.8            6685           76381  cudaEventSynchronize
#    16.7         5901937         801          7368.2            6094           39469  cudaLaunchKernel
#    10.4         3698816        1202          3077.2            2513           20109  cudaEventRecord
#     5.8         2069660         635          3259.3            2870           12909  cudaDeviceSynchronize
#     1.8          649615          20         32480.8            4242          159293  cudaMalloc
#     0.8          299330          13         23025.4           15441           35930  cudaMemcpy
#     0.6          213583          13         16429.5            3121          143459  cudaFree
#     0.0            4430           2          2215.0            1270            3160  cudaEventCreate
#     0.0            4282           2          2141.0            1586            2696  cudaEventDestroy
#
#
#
#
# Generating CUDA Kernel Statistics...
# CUDA Kernel Statistics (nanoseconds)
#
# Time(%)      Total Time   Instances         Average         Minimum         Maximum  Name
# -------  --------------  ----------  --------------  --------------  --------------  --------------------------------------------------------------------------------------------------------------------
#    27.1         5804534         100         58045.3           51939           63235  CoGKernel(int, int, int volatile*, int const*, float volatile*, float volatile*, float volatile*, float volatile*)
#    24.0         5143128         100         51431.3           48898           54338  BoundingBoxKernel(int, int, int volatile*, int volatile*, float volatile*, float volatile*, float volatile*, float volatile*, float volatile*, float volatile*, float volatile*, float volatile*, float volatile*, float volatile*)
#    24.0         5140179         100         51401.8           44930           60131  TreeBuildingKernel(int, int, int volatile*, float volatile*, float volatile*, float volatile*)
#    15.6         3344570         100         33445.7           30305           37250  SortKernel(int, int, int*, int*, int volatile*, int*)
#     6.2         1323894         100         13238.9           10144           13824  ForceKernel(int, int, float, float, float, int volatile*, int volatile*, float volatile*, float volatile*, float volatile*, float volatile*, float volatile*, float volatile*, float volatile*, float volatile*, float volatile*, float volatile*)
#     1.3          268558         100          2685.6            2592            6176  InitializationKernel1(int, int, int volatile*)
#     1.2          259414         100          2594.1            2528            2817  UpdateKernel(int, float, float, float*, float*, float*, float*, float*, float*, float*, float*, float*)
#     0.7          146184         100          1461.8            1409            1664  InitializationKernel2(int, int volatile*, float volatile*)
#     0.0            2944           1          2944.0            2944            2944  InitializationKernel()
#
#
#
# Generating CUDA Memory Operation Statistics...
# CUDA Memory Operation Statistics (nanoseconds)
#
# Time(%)      Total Time  Operations         Average         Minimum         Maximum  Name
# -------  --------------  ----------  --------------  --------------  --------------  --------------------------------------------------------------------------------
#    62.7           41441           7          5920.1            5920            5921  [CUDA memcpy HtoD]
#    37.3           24642           6          4107.0            4000            4545  [CUDA memcpy DtoH]
#
#
# CUDA Memory Operation Statistics (KiB)
#
#               Total      Operations              Average            Minimum              Maximum  Name
# -------------------  --------------  -------------------  -----------------  -------------------  --------------------------------------------------------------------------------
#             273.438               7               39.063             39.063               39.063  [CUDA memcpy HtoD]
#             234.375               6               39.063             39.063               39.063  [CUDA memcpy DtoH]
#
#
#
#
# Generating Operating System Runtime API Statistics...
# Operating System Runtime API Statistics (nanoseconds)
#
# Time(%)      Total Time       Calls         Average         Minimum         Maximum  Name
# -------  --------------  ----------  --------------  --------------  --------------  --------------------------------------------------------------------------------
#    51.9       321587187          13      24737475.9           25245       100131452  sem_timedwait
#    32.2       199835876          12      16652989.7           41924        98176823  poll
#    15.2        94324447         582        162069.5            1055        21157264  ioctl
#     0.4         2673618          78         34277.2            1747          800980  mmap
#     0.1          719309          73          9853.5            4256           30713  open64
#     0.0          168799           4         42199.8           39093           47552  pthread_create
#     0.0          116126          21          5529.8            1639           17394  fopen
#     0.0          107397          10         10739.7            7127           13810  write
#     0.0           92427           3         30809.0           22892           44973  fgets
#     0.0           77335          71          1089.2            1011            1305  fcntl
#     0.0           39081          14          2791.5            1637            4429  fclose
#     0.0           38547           5          7709.4            4495           12313  open
#     0.0           29175           8          3646.9            1597            5657  munmap
#     0.0           27975          12          2331.3            1396            3707  read
#     0.0           17591           3          5863.7            4813            6450  pipe2
#     0.0           10610           2          5305.0            5194            5416  socket
#     0.0            9804           4          2451.0            2408            2515  mprotect
#     0.0            7252           1          7252.0            7252            7252  connect
#     0.0            2587           1          2587.0            2587            2587  bind
#     0.0            1974           1          1974.0            1974            1974  listen
#
#
#
#
# Generating NVTX Push-Pop Range Statistics...
# NVTX Push-Pop Range Statistics (nanoseconds)
#
#
#
#
# Report file moved to "/dli/task/BarnesHut-SharedMemory/barnesHutProfile.qdrep"
# Report file moved to "/dli/task/BarnesHut-SharedMemory/barnesHutProfile.sqlite"
